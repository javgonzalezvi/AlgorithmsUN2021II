# %% [markdown]
# <a href="https://colab.research.google.com/github/javgonzalezvi/AlgorithmsUN2022I/blob/master/Lab8/BubbleSortOptDistributionWithoutRepGroup9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Bubble sort optimized time complexity, and time complexity histograms for permutations of n different elements**

# %%
def optimized_bubble_sort(lista):

  comps = 0
  swaps = 0
  steps = 0
  passes = 0 
  n = len(lista)

  for i in range(0,n):
    passes +=1
    stop = True
        
    for j in range(0,n-1): 
      comps +=1
      if lista[j] > lista[j+1]:
        lista[j], lista[j+1] = lista[j+1], lista[j]
        stop = False
        swaps +=1

      if stop:
            break
            
  steps = comps + swaps 
  return (comps,swaps,steps,passes)

# %%
def maxinversions(lista):
  maxinv = 0
  n = len(lista) 
  for i in range(n-1):
    inv = 0
    for j in range(i+1,n):
      if lista[j] < lista[i]:
        inv +=1
    if inv > maxinv:
      maxinv = inv
  return maxinv

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 3
perm = permutations(range(1,n+1))

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    c,sw,st,p = optimized_bubble_sort(i)
    comps.append(c)
    swaps.append(sw)
    steps.append(st)
    passes.append(p)

print(maxinvs)
print("n",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cyan")
plt.title("Bubble Sort Maximun number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximun number of inversions") 
print("Maximun number of inversions exper min =",min(maxinvs))
print("Maximun number of inversions formula min = 0")
print("Maximun number of inversions exper max =",max(maxinvs))
print("Maximun number of inversions formula max n-1 =",n-1)
print("Maximun number of inversions exper mean =",np.mean(maxinvs))
print("Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)=", np.mean(maxinvs))
print("Maximun number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="red")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons exper min =",min(comps))
print("Comparisons min formula n-1 =",n-1)
print("Comparisonsexper max =",max(comps))
print("Comparisons average formula (n^2-n)/2 =",(n**2-n)/2)
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons average formula (n^2+n-2)/4 =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="blue")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (n-1)*n/4 =",(n-1)*n/4)
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (n^2-1)/2 =",np.mean(steps))
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="brown")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# [0, 1, 1, 1, 2, 2]
# n 3
# number of permutations n! = 6
# Maximun number of inversions
# Maximun number of inversions exper min = 0
# Maximun number of inversions formula min = 0
# Maximun number of inversions exper max = 2
# Maximun number of inversions formula max n-1 = 2
# Maximun number of inversions exper mean = 1.1666666666666667
# Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 1.1666666666666667
# Maximun number of inversions exper stdev = 0.6871842709362768
# Comparisons
# Comparisons exper min = 3
# Comparisons min formula n-1 = 2
# Comparisonsexper max = 5
# Comparisons average formula (n^2-n)/2 = 3.0
# Comparisons exper mean = 3.6666666666666665
# Comparisons average formula (n^2+n-2)/4 = 3.6666666666666665
# Comparisons exper stdev = 0.7453559924999298
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 3
# Swaps max formula (n-1)*n/2 = 3.0
# Swaps exper mean = 1.0
# Swaps mean formula (n-1)*n/4 = 1.5
# Swaps exper stdev = 1.1547005383792515
# Steps
# Steps exper min = 3
# Steps min formula (n-1) = 2
# Steps exper max = 8
# Steps max formula (n-1)*n = 6
# Steps exper mean = 4.666666666666667
# Steps mean formula (n^2-1)/2 = 4.666666666666667
# Steps exper stdev 1.8856180831641267
# Passes
# Passes formula (n-1) = 2
# Passes exper min = 3
# Passes exper max = 3
# Passes exper mean = 3.0
# Passes exper stdev 0.0

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 5
perm = permutations(range(1,n+1))

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    c,sw,st,p = optimized_bubble_sort(i)
    comps.append(c)
    swaps.append(sw)
    steps.append(st)
    passes.append(p)

print("n =",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cyan")
plt.title("Bubble Sort Maximun number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximun number of inversions") 
print("Maximun number of inversions exper min =",min(maxinvs))
print("Maximun number of inversions formula min = 0")
print("Maximun number of inversions exper max =",max(maxinvs))
print("Maximun number of inversions formula max n-1 =",n-1)
print("Maximun number of inversions exper mean =",np.mean(maxinvs))
print("Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",n- math.sqrt(math.pi*n/2))
print("Maximun number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="red")
plt.title("Bubble Sort Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons formula (n-1)*n/2 =",(n-1)*n/2)
print("Comparisons exper min =",min(comps))
print("Comparisonsexper max =",max(comps))
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="blue")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (n-1)*n/4 =",(n-1)*n/4)
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (3/4)*(n**2-n) =",(3/4)*(n**2-n))
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="brown")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n = 5
# number of permutations n! = 120
# Maximun number of inversions
# Maximun number of inversions exper min = 0
# Maximun number of inversions formula min = 0
# Maximun number of inversions exper max = 4
# Maximun number of inversions formula max n-1 = 4
# Maximun number of inversions exper mean = 2.6083333333333334
# Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 2.1975043918010355
# Maximun number of inversions exper stdev = 0.9686402267554702
# Comparisons
# Comparisons formula (n-1)*n/2 = 10.0
# Comparisons exper min = 5
# Comparisonsexper max = 17
# Comparisons exper mean = 7.15
# Comparisons exper stdev = 2.6033632093889625
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 10
# Swaps max formula (n-1)*n/2 = 10.0
# Swaps exper mean = 2.025
# Swaps mean formula (n-1)*n/4 = 5.0
# Swaps exper stdev = 2.399522521947509
# Steps
# Steps exper min = 5
# Steps min formula (n-1)*n/2 = 10.0
# Steps exper max = 27
# Steps max formula (n-1)*n = 20
# Steps exper mean = 9.175
# Steps mean formula (3/4)*(n**2-n) = 15.0
# Steps exper stdev 4.95254564172137
# Passes
# Passes formula (n-1) = 4
# Passes exper min = 5
# Passes exper max = 5
# Passes exper mean = 5.0
# Passes exper stdev 0.0

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 8
perm = permutations(range(1,n+1))

comps = []
swaps = []
steps = []
passes = [] 
maxinvs = []

# Print the obtained permutations
for i in perm:
    i = list(i)
    maxinvs.append(maxinversions(i))
    c,sw,st,p = optimized_bubble_sort(i)
    comps.append(c)
    swaps.append(sw)
    steps.append(st)
    passes.append(p)

print("n",n)  
print("number of permutations n! =",math.factorial(n)) 
print()
   
b = np.array(range(min(maxinvs)-1,max(maxinvs)+2) ) +0.5
plt.hist(maxinvs,bins=b, color="cyan")
plt.title("Bubble Sort Maximun number of inversions")
plt.xlabel("Maximun number of inversions ")
plt.ylabel("Frequency")
plt.show()

print("Maximun number of inversions") 
print("Maximun number of inversions exper min =",min(maxinvs))
print("Maximun number of inversions formula min = 0")
print("Maximun number of inversions exper max =",max(maxinvs))
print("Maximun number of inversions formula max n-1 =",n-1)
print("Maximun number of inversions exper mean =",np.mean(maxinvs))
print("Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)=",np.mean(maxinvs))
print("Maximun number of inversions exper stdev =",np.std(maxinvs))
print()

b = np.array(range(min(comps)-1,max(comps)+2) ) +0.5
plt.hist(comps,bins=b, color="red")
plt.title("Bubble Sor Comparisons")
plt.xlabel("Comparisons ")
plt.ylabel("Frequency")
plt.show()

print("Comparisons") 
print("Comparisons exper min =",min(comps))
print("Comparisons min formula n-1 =",n-1)
print("Comparisonsexper max =",max(comps))
print("Comparisons average formula (n^2-n)/2 =",(n**2-n)/2)
print("Comparisons exper mean =",np.mean(comps))
print("Comparisons average formula (n^2+n-2)/4 =",np.mean(comps))
print("Comparisons exper stdev =",np.std(comps))
print()

b = np.array(range(min(swaps)-1,max(swaps)+2) ) +0.5
plt.hist(swaps,bins=b,color="blue")
plt.title("Bubble Sort Swaps")
plt.xlabel("Swaps ")
plt.ylabel("Frequency")
plt.show()

print("Swaps") 
print("Swaps exper min =",min(swaps))
print("Swaps min formula = 0")
print("Swaps exper max =",max(swaps))
print("Swaps max formula (n-1)*n/2 =",(n-1)*n/2)
print("Swaps exper mean =",np.mean(swaps))
print("Swaps mean formula (n-1)*n/4 =",(n-1)*n/4)
print("Swaps exper stdev =",np.std(swaps))
print()

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1) =",(n-1))
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (n^2-1)/2 =",np.mean(steps))
print("Steps exper stdev",np.std(steps))
print()

b = np.array(range(min(passes)-1,max(passes)+2) ) +0.5
plt.hist(passes,bins=b,color="brown")
plt.title("Bubble Sort Passes")
plt.xlabel("Passes")
plt.ylabel("Frequency")
plt.show()
    
print("Passes") 
print("Passes formula (n-1) =",(n-1))
print("Passes exper min =",min(passes))
print("Passes exper max =",max(passes))
print("Passes exper mean =",np.mean(passes))
print("Passes exper stdev",np.std(passes))
# Out:
# n 8
# number of permutations n! = 40320
# Maximun number of inversions
# Maximun number of inversions exper min = 0
# Maximun number of inversions formula min = 0
# Maximun number of inversions exper max = 7
# Maximun number of inversions formula max n-1 = 7
# Maximun number of inversions exper mean = 4.9183779761904765
# Maximun number of inversions formula mean  n- math.sqrt(math.pi*n/2)= 4.9183779761904765
# Maximun number of inversions exper stdev = 1.3258568463357079
# Comparisons
# Comparisons exper min = 8
# Comparisons min formula n-1 = 7
# Comparisonsexper max = 50
# Comparisons average formula (n^2-n)/2 = 28.0
# Comparisons exper mean = 12.30967261904762
# Comparisons average formula (n^2+n-2)/4 = 12.30967261904762
# Comparisons exper stdev = 5.250419077374663
# Swaps
# Swaps exper min = 0
# Swaps min formula = 0
# Swaps exper max = 28
# Swaps max formula (n-1)*n/2 = 28.0
# Swaps exper mean = 3.7466765873015873
# Swaps mean formula (n-1)*n/4 = 14.0
# Swaps exper stdev = 4.38925273254641
# Steps
# Steps exper min = 8
# Steps min formula (n-1) = 7
# Steps exper max = 78
# Steps max formula (n-1)*n = 56
# Steps exper mean = 16.056349206349207
# Steps mean formula (n^2-1)/2 = 16.056349206349207
# Steps exper stdev 9.569039514353635
# Passes
# Passes formula (n-1) = 7
# Passes exper min = 8
# Passes exper max = 8
# Passes exper mean = 8.0
# Passes exper stdev 0.0

# %%
def steps_optimized_bubble_sort(lista):

  steps = 0
  n = len(lista)

  for i in range(0,n):
    newn = 0
    for j in range(0,n-1): 
      steps +=1
      if lista[j] > lista[j+1]:
        lista[j], lista[j+1] = lista[j+1], lista[j]
        newn = j
        steps +=1
    n = newn + 1

  return (steps)

# %%
from itertools import permutations
import matplotlib.pyplot as plt
import numpy as np 
import math

n = 8
perm = permutations(range(1,n+1))

times =  [] 
# Print the obtained permutations
for i in perm:
    i = list(i)
    times.append(steps_optimized_bubble_sort(i))

b = np.array(range(min(steps)-1,max(steps)+2) ) +0.5
plt.hist(steps,bins=b,color="green")
plt.title("Bubble Sort Steps")
plt.xlabel("Steps ")
plt.ylabel("Frequency")
plt.show()

print("Steps") 
print("Steps exper min =",min(steps))
print("Steps min formula (n-1)*n/2 =",(n-1)*n/2)
print("Steps exper max =",max(steps))
print("Steps max formula (n-1)*n =",(n-1)*n)
print("Steps exper mean =",np.mean(steps))
print("Steps mean formula (3/4)*(n**2-n) =",(3/4)*(n**2-n))
print("Steps exper stdev",np.std(steps))
print()
# Out:
# Steps
# Steps exper min = 5
# Steps min formula (n-1)*n/2 = 28.0
# Steps exper max = 27
# Steps max formula (n-1)*n = 56
# Steps exper mean = 9.175
# Steps mean formula (3/4)*(n**2-n) = 42.0
# Steps exper stdev 4.95254564172137

# %%
# https://towardsdatascience.com/an-easy-introduction-to-3d-plotting-with-matplotlib-801561999725
from itertools import permutations
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import random 

fig = plt.figure()
ax = plt.axes(projection="3d")

N = 8

x = []
y = []
z = []
dx = []
dy = []
dz = []

for n in np.arange(3,N+1,1):
   A = range(n)
   times = []

   for P in permutations(A):
       t = steps_optimized_bubble_sort(list(P)) 
       times.append(t)  
 
   b = np.array(range(min(times)-1, max(times)+1))+0.5
   H = np.array(np.histogram(times,b))
   H[0] = H[0]/np.sum(H[0])
   for i in range(len(H[0])):
     x.append(n)
     y.append(H[1][i])
     z.append(0)
     dx.append(0.1)
     dy.append(0.1)
     dz.append(H[0][i])

ax.bar3d(x, y, z, dx, dy, dz, color='palegreen', zsort='average')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
